# %% [markdown]
# # ⎝乡<font color='greenr'> Any link   </font> upload to  <font color='lightblue'>Mega</font> <img src='https://cdn-icons-png.flaticon.com/512/873/873133.png' height="100" />BY'-  <font color='red'> ツ  Parvej Sorkar   ⎝⎝乡 </font>

# %% [markdown]
# <font color='pink'> Tools  </font>
#
#
# *   <font color='yellow'> Rclone </font> - download rclone in your operating system download link= https://rclone.org/downloads/
# *   <font color='yellow'> Megadrive Account  </font> (personal,business both working) no account? just signup https://signup.live.com/

# %% [markdown]
# # 1.Install  <img src='https://biplobsd.github.io/RLabClone/img/title_rclonelab.svg' height="45" alt="RcloneLab"/>

# %%
# !python -m pip install --upgrade pip setuptools wheel
# !wget https://downloads.rclone.org/v1.52.1/rclone-v1.52.1-linux-amd64.deb
# !apt install ./rclone-v1.52.1-linux-amd64.deb

# %% [markdown]
# # 2.<font color='orange'>Authenticate One Drive </font> <img src='https://biplobsd.github.io/RLabClone/img/title_rclonelab.svg' height="45" alt="RcloneLab"/></font>

# %%
# !rclone config      #add your onedrive

# %% [markdown]
# <img src='https://cdn.vox-cdn.com/uploads/chorus_asset/file/12410821/Confused_Ice_Cube.0.gif' height="150" />
#
# #</font> <font color='red'> CAN'T CONFIG?  </font>  follow this,
#
# 1.type </font> <font color='red'>"n"  </font>        - new remote
#
# 2.type</font> <font color='red'> onedrive </font> -name
#
# 3.type </font> <font color='red'>"21"  </font>  -storage
#
# 4.press </font> <font color='red'> enter </font>      -client id
#
# 5.press </font> <font color='red'>enter </font>      -client secret
#
# 6.type </font> <font color='red'>"n"  </font>     -edit advanced no
#
# 7.type</font> <font color='red'>"n"  </font>      -auto config no
#
# 8.</font> <font color='gree'>get rclone Authenticate Mega Drive code and paste and press enter </font> </font> <font color='red'>GET CODE? </font>
#
# 9.type</font> <font color='red'>"1"  </font>'
#
# 10.type'</font> <font color='red'>"0"  </font>
#
# 11.type</font> <font color='red'>"y"  </font>
#
# 12.type</font> <font color='red'>"y"  </font>
#
# 13.type  </font> <font color='red'>"q"  </font>

# %% [markdown]
# # 3.Rclone<font color='yellow'>  Mount mega drive <img src='https://cdn-icons-png.flaticon.com/512/873/873133.png' height="90" />

# %%
# !mkdir mega
# !nohup rclone --vfs-cache-mode writes mount mega: ./mega &

# %% [markdown]
# check onedrive mounted

# %%
# !ls ./mega    #after sucessfully mounted Mega drive then show your onedrive folders and files

# %% [markdown]
# # 4.Add <font color='orange'> any link add and downlod to mega  <img src='https://dcblog.b-cdn.net/wp-content/uploads/2021/02/Full-form-of-URL-1.jpg' height="45" alt="RcloneLab"/>

# %%
# !wget -P /content/drive/MyDrive/newFolder/ https://ia803409.us.archive.org/19/items/rutor.is-cyberpunk-2077-fit-girl-repack_202105/fg-02.bin
